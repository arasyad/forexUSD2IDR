# %%
# !pip install python-Levenshtein
# Out:
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.10/dist-packages (0.21.1)
# Requirement already satisfied: Levenshtein==0.21.1 in /usr/local/lib/python3.10/dist-packages (from python-Levenshtein) (0.21.1)
# Requirement already satisfied: rapidfuzz<4.0.0,>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from Levenshtein==0.21.1->python-Levenshtein) (3.1.1)

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# convert an array of values into a dataset matrix
def create_dataset(dataset, look_back=1):
 dataX, dataY = [], []
 for i in range(len(dataset)-look_back-1):
    a = dataset[i:(i+look_back), 0]
    dataX.append(a)
    dataY.append(dataset[i + look_back, 0])
 return np.array(dataX), np.array(dataY)

# fix random seed for reproducibility
tf.random.set_seed(7)

# %% [markdown]
# USD/IDR Exchange Rate from Jan 2013 - May 2023

# %%
start_date = '2013-01-01'
# start_date_temp = '2008-07-01'

end_date = '2023-06-01'
# end_date_temp = '2009-07-01'

data_download = yf.download('USDIDR=X', start=start_date, end=end_date, progress=False)
data = data_download.drop(['Open',
                 'High',
                 'Low',
                 'Adj Close',
                 'Volume'],axis=1)
data
# Out:
#                    Close
# Date
# 2013-01-01   9609.000000
# 2013-01-02   9609.000000
# 2013-01-03   9622.500000
# 2013-01-04   9626.299805
# 2013-01-07   9770.000000
# ...                  ...
# 2023-05-25  14945.900391
# 2023-05-26  14970.000000
# 2023-05-29  14948.000000
# 2023-05-30  14960.000000
# 2023-05-31  14979.000000
#
# [2713 rows x 1 columns]

# %% [markdown]
# Temporal Analysis

# %%
# extracting only the close values
values = pd.DataFrame(data['Close'])

# using shift function to shift the values.
time_series = pd.concat([values.shift(i) for i in range(7, -2, -1)], axis=1)

# rename columns
time_series.columns = [f't-{i}'for i in range(7, -2, -1)]
time_series.columns = [i.replace('--', '+') for i in time_series.columns]
time_series.columns = [i.replace('t-0', 'Actual Close') for i in time_series.columns]

# using shift function to shift the values.
time_series = pd.concat([values.shift(i) for i in range(2, -2, -1)], axis=1)

# rename columns
time_series.columns = ['t-2', 't-1', 'Actual Close', 't+1']

# remove NaN
time_series = time_series[2:]
time_series = time_series[:2710]

time_series
# Out:
#                      t-2           t-1  Actual Close           t+1
# Date
# 2013-01-03   9609.000000   9609.000000   9622.500000   9626.299805
# 2013-01-04   9609.000000   9622.500000   9626.299805   9770.000000
# 2013-01-07   9622.500000   9626.299805   9770.000000   9639.099609
# 2013-01-08   9626.299805   9770.000000   9639.099609   9641.200195
# 2013-01-09   9770.000000   9639.099609   9641.200195   9632.099609
# ...                  ...           ...           ...           ...
# 2023-05-24  14918.000000  14886.000000  14895.000000  14945.900391
# 2023-05-25  14886.000000  14895.000000  14945.900391  14970.000000
# 2023-05-26  14895.000000  14945.900391  14970.000000  14948.000000
# 2023-05-29  14945.900391  14970.000000  14948.000000  14960.000000
# 2023-05-30  14970.000000  14948.000000  14960.000000  14979.000000
#
# [2710 rows x 4 columns]

# %%
time_series_output = time_series.drop(['t-2',
                                       't-1',
                                       'Actual Close',],axis=1)

time_series_output
# Out:
#                      t+1
# Date
# 2013-01-03   9626.299805
# 2013-01-04   9770.000000
# 2013-01-07   9639.099609
# 2013-01-08   9641.200195
# 2013-01-09   9632.099609
# ...                  ...
# 2023-05-24  14945.900391
# 2023-05-25  14970.000000
# 2023-05-26  14948.000000
# 2023-05-29  14960.000000
# 2023-05-30  14979.000000
#
# [2710 rows x 1 columns]

# %%
time_series_actual = time_series.drop(['t-2',
                                       't-1',
                                       't+1'],axis=1)

time_series_actual
# Out:
#             Actual Close
# Date
# 2013-01-03   9622.500000
# 2013-01-04   9626.299805
# 2013-01-07   9770.000000
# 2013-01-08   9639.099609
# 2013-01-09   9641.200195
# ...                  ...
# 2023-05-24  14895.000000
# 2023-05-25  14945.900391
# 2023-05-26  14970.000000
# 2023-05-29  14948.000000
# 2023-05-30  14960.000000
#
# [2710 rows x 1 columns]

# %%
# normalize the dataset
scaler = MinMaxScaler(feature_range=(0, 1))
time_series = scaler.fit_transform(time_series)

time_series
# Out:
# array([[0.0028342 , 0.0028342 , 0.00478636, 0.00533583],
#        [0.0028342 , 0.00478636, 0.00533583, 0.02611557],
#        [0.00478636, 0.00533583, 0.02611557, 0.00718674],
#        ...,
#        [0.7672151 , 0.77457554, 0.77806046, 0.77487915],
#        [0.77457554, 0.77806046, 0.77487915, 0.77661441],
#        [0.77806046, 0.77487915, 0.77661441, 0.7793619 ]])

# %%
# normalize the dataset
scaler_output = MinMaxScaler(feature_range=(0, 1))
time_series_output = scaler_output.fit_transform(time_series_output)

time_series_output
# Out:
# array([[0.00533583],
#        [0.02611557],
#        [0.00718674],
#        ...,
#        [0.77487915],
#        [0.77661441],
#        [0.7793619 ]])

# %% [markdown]
# Split Data into 80/20

# %%
# split into train and test sets
train_size = int(len(time_series) * 0.8)
test_size = len(time_series) - train_size
train, test = time_series[0:train_size,:], time_series[train_size:len(time_series),:]

# reshape into X=t and Y=t+1
look_back = 3
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# reshape input to be [samples, time steps, features]
trainX = np.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
testX = np.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %% [markdown]
# LSTM Model

# %%
# create and fit the LSTM network
model = Sequential()
model.add(LSTM(4, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=100, batch_size=1, verbose=2)

# make predictions
trainPredict = model.predict(trainX)
testPredict = model.predict(testX)
# Out:
# Epoch 1/100
# 2164/2164 - 5s - loss: 0.0068 - 5s/epoch - 2ms/step
# Epoch 2/100
# 2164/2164 - 3s - loss: 6.8595e-04 - 3s/epoch - 2ms/step
# Epoch 3/100
# 2164/2164 - 3s - loss: 6.9661e-04 - 3s/epoch - 2ms/step
# Epoch 4/100
# 2164/2164 - 3s - loss: 6.6685e-04 - 3s/epoch - 1ms/step
# Epoch 5/100
# 2164/2164 - 3s - loss: 6.8601e-04 - 3s/epoch - 2ms/step
# Epoch 6/100
# 2164/2164 - 4s - loss: 6.7755e-04 - 4s/epoch - 2ms/step
# Epoch 7/100
# 2164/2164 - 3s - loss: 6.6815e-04 - 3s/epoch - 1ms/step
# Epoch 8/100
# 2164/2164 - 3s - loss: 6.6044e-04 - 3s/epoch - 1ms/step
# Epoch 9/100
# 2164/2164 - 3s - loss: 6.5926e-04 - 3s/epoch - 1ms/step
# Epoch 10/100
# 2164/2164 - 3s - loss: 6.5871e-04 - 3s/epoch - 2ms/step
# Epoch 11/100
# 2164/2164 - 3s - loss: 6.4807e-04 - 3s/epoch - 1ms/step
# Epoch 12/100
# 2164/2164 - 3s - loss: 6.3585e-04 - 3s/epoch - 1ms/step
# Epoch 13/100
# 2164/2164 - 3s - loss: 6.4105e-04 - 3s/epoch - 2ms/step
# Epoch 14/100
# 2164/2164 - 3s - loss: 6.3489e-04 - 3s/epoch - 2ms/step
# Epoch 15/100
# 2164/2164 - 3s - loss: 6.4082e-04 - 3s/epoch - 1ms/step
# Epoch 16/100
# 2164/2164 - 3s - loss: 6.3437e-04 - 3s/epoch - 1ms/step
# Epoch 17/100
# 2164/2164 - 4s - loss: 6.4175e-04 - 4s/epoch - 2ms/step
# Epoch 18/100
# 2164/2164 - 3s - loss: 6.3297e-04 - 3s/epoch - 1ms/step
# Epoch 19/100
# 2164/2164 - 3s - loss: 6.3692e-04 - 3s/epoch - 2ms/step
# Epoch 20/100
# 2164/2164 - 3s - loss: 6.3044e-04 - 3s/epoch - 2ms/step
# Epoch 21/100
# 2164/2164 - 3s - loss: 6.3670e-04 - 3s/epoch - 2ms/step
# Epoch 22/100
# 2164/2164 - 3s - loss: 6.3992e-04 - 3s/epoch - 1ms/step
# Epoch 23/100
# 2164/2164 - 3s - loss: 6.2996e-04 - 3s/epoch - 1ms/step
# Epoch 24/100
# 2164/2164 - 4s - loss: 6.3942e-04 - 4s/epoch - 2ms/step
# Epoch 25/100
# 2164/2164 - 3s - loss: 6.3066e-04 - 3s/epoch - 1ms/step
# Epoch 26/100
# 2164/2164 - 3s - loss: 6.3318e-04 - 3s/epoch - 1ms/step
# Epoch 27/100
# 2164/2164 - 3s - loss: 6.3005e-04 - 3s/epoch - 2ms/step
# Epoch 28/100
# 2164/2164 - 4s - loss: 6.3822e-04 - 4s/epoch - 2ms/step
# Epoch 29/100
# 2164/2164 - 3s - loss: 6.3329e-04 - 3s/epoch - 2ms/step
# Epoch 30/100
# 2164/2164 - 3s - loss: 6.2981e-04 - 3s/epoch - 2ms/step
# Epoch 31/100
# 2164/2164 - 4s - loss: 6.2853e-04 - 4s/epoch - 2ms/step
# Epoch 32/100
# 2164/2164 - 3s - loss: 6.2362e-04 - 3s/epoch - 1ms/step
# Epoch 33/100
# 2164/2164 - 3s - loss: 6.4049e-04 - 3s/epoch - 1ms/step
# Epoch 34/100
# 2164/2164 - 3s - loss: 6.3009e-04 - 3s/epoch - 2ms/step
# Epoch 35/100
# 2164/2164 - 3s - loss: 6.3179e-04 - 3s/epoch - 2ms/step
# Epoch 36/100
# 2164/2164 - 3s - loss: 6.3657e-04 - 3s/epoch - 1ms/step
# Epoch 37/100
# 2164/2164 - 3s - loss: 6.2814e-04 - 3s/epoch - 2ms/step
# Epoch 38/100
# 2164/2164 - 4s - loss: 6.3440e-04 - 4s/epoch - 2ms/step
# Epoch 39/100
# 2164/2164 - 3s - loss: 6.3328e-04 - 3s/epoch - 1ms/step
# Epoch 40/100
# 2164/2164 - 3s - loss: 6.2814e-04 - 3s/epoch - 1ms/step
# Epoch 41/100
# 2164/2164 - 3s - loss: 6.3009e-04 - 3s/epoch - 2ms/step
# Epoch 42/100
# 2164/2164 - 4s - loss: 6.1924e-04 - 4s/epoch - 2ms/step
# Epoch 43/100
# 2164/2164 - 3s - loss: 6.1301e-04 - 3s/epoch - 1ms/step
# Epoch 44/100
# 2164/2164 - 3s - loss: 6.2354e-04 - 3s/epoch - 1ms/step
# Epoch 45/100
# 2164/2164 - 4s - loss: 6.2040e-04 - 4s/epoch - 2ms/step
# Epoch 46/100
# 2164/2164 - 3s - loss: 6.2845e-04 - 3s/epoch - 1ms/step
# Epoch 47/100
# 2164/2164 - 3s - loss: 6.2465e-04 - 3s/epoch - 1ms/step
# Epoch 48/100
# 2164/2164 - 3s - loss: 6.2008e-04 - 3s/epoch - 2ms/step
# Epoch 49/100
# 2164/2164 - 4s - loss: 6.2322e-04 - 4s/epoch - 2ms/step
# Epoch 50/100
# 2164/2164 - 3s - loss: 6.2178e-04 - 3s/epoch - 1ms/step
# Epoch 51/100
# 2164/2164 - 3s - loss: 6.2158e-04 - 3s/epoch - 1ms/step
# Epoch 52/100
# 2164/2164 - 4s - loss: 6.2228e-04 - 4s/epoch - 2ms/step
# Epoch 53/100
# 2164/2164 - 3s - loss: 6.2392e-04 - 3s/epoch - 1ms/step
# Epoch 54/100
# 2164/2164 - 3s - loss: 6.1420e-04 - 3s/epoch - 1ms/step
# Epoch 55/100
# 2164/2164 - 3s - loss: 6.2660e-04 - 3s/epoch - 1ms/step
# Epoch 56/100
# 2164/2164 - 4s - loss: 6.1755e-04 - 4s/epoch - 2ms/step
# Epoch 57/100
# 2164/2164 - 3s - loss: 6.2153e-04 - 3s/epoch - 2ms/step
# Epoch 58/100
# 2164/2164 - 3s - loss: 6.2358e-04 - 3s/epoch - 1ms/step
# Epoch 59/100
# 2164/2164 - 4s - loss: 6.2206e-04 - 4s/epoch - 2ms/step
# Epoch 60/100
# 2164/2164 - 3s - loss: 6.1231e-04 - 3s/epoch - 1ms/step
# Epoch 61/100
# 2164/2164 - 3s - loss: 6.1969e-04 - 3s/epoch - 1ms/step
# Epoch 62/100
# 2164/2164 - 3s - loss: 6.2975e-04 - 3s/epoch - 1ms/step
# Epoch 63/100
# 2164/2164 - 4s - loss: 6.2766e-04 - 4s/epoch - 2ms/step
# Epoch 64/100
# 2164/2164 - 3s - loss: 6.1457e-04 - 3s/epoch - 1ms/step
# Epoch 65/100
# 2164/2164 - 3s - loss: 6.1743e-04 - 3s/epoch - 1ms/step
# Epoch 66/100
# 2164/2164 - 4s - loss: 6.1622e-04 - 4s/epoch - 2ms/step
# Epoch 67/100
# 2164/2164 - 3s - loss: 6.2328e-04 - 3s/epoch - 1ms/step
# Epoch 68/100
# 2164/2164 - 3s - loss: 6.0354e-04 - 3s/epoch - 1ms/step
# Epoch 69/100
# 2164/2164 - 3s - loss: 6.1167e-04 - 3s/epoch - 1ms/step
# Epoch 70/100
# 2164/2164 - 4s - loss: 6.1016e-04 - 4s/epoch - 2ms/step
# Epoch 71/100
# 2164/2164 - 3s - loss: 6.1722e-04 - 3s/epoch - 1ms/step
# Epoch 72/100
# 2164/2164 - 3s - loss: 6.0841e-04 - 3s/epoch - 2ms/step
# Epoch 73/100
# 2164/2164 - 4s - loss: 6.1942e-04 - 4s/epoch - 2ms/step
# Epoch 74/100
# 2164/2164 - 3s - loss: 6.1158e-04 - 3s/epoch - 2ms/step
# Epoch 75/100
# 2164/2164 - 3s - loss: 6.1529e-04 - 3s/epoch - 1ms/step
# Epoch 76/100
# 2164/2164 - 3s - loss: 6.0897e-04 - 3s/epoch - 2ms/step
# Epoch 77/100
# 2164/2164 - 4s - loss: 6.0447e-04 - 4s/epoch - 2ms/step
# Epoch 78/100
# 2164/2164 - 3s - loss: 6.1255e-04 - 3s/epoch - 1ms/step
# Epoch 79/100
# 2164/2164 - 3s - loss: 6.1752e-04 - 3s/epoch - 2ms/step
# Epoch 80/100
# 2164/2164 - 4s - loss: 6.1398e-04 - 4s/epoch - 2ms/step
# Epoch 81/100
# 2164/2164 - 3s - loss: 6.1326e-04 - 3s/epoch - 1ms/step
# Epoch 82/100
# 2164/2164 - 3s - loss: 6.0913e-04 - 3s/epoch - 1ms/step
# Epoch 83/100
# 2164/2164 - 3s - loss: 6.0683e-04 - 3s/epoch - 2ms/step
# Epoch 84/100
# 2164/2164 - 4s - loss: 6.0264e-04 - 4s/epoch - 2ms/step
# Epoch 85/100
# 2164/2164 - 3s - loss: 6.1997e-04 - 3s/epoch - 1ms/step
# Epoch 86/100
# 2164/2164 - 3s - loss: 6.1283e-04 - 3s/epoch - 2ms/step
# Epoch 87/100
# 2164/2164 - 4s - loss: 6.0452e-04 - 4s/epoch - 2ms/step
# Epoch 88/100
# 2164/2164 - 3s - loss: 6.0948e-04 - 3s/epoch - 1ms/step
# Epoch 89/100
# 2164/2164 - 3s - loss: 5.9770e-04 - 3s/epoch - 2ms/step
# Epoch 90/100
# 2164/2164 - 3s - loss: 6.0192e-04 - 3s/epoch - 1ms/step
# Epoch 91/100
# 2164/2164 - 4s - loss: 6.1390e-04 - 4s/epoch - 2ms/step
# Epoch 92/100
# 2164/2164 - 3s - loss: 6.0471e-04 - 3s/epoch - 1ms/step
# Epoch 93/100
# 2164/2164 - 3s - loss: 6.0417e-04 - 3s/epoch - 1ms/step
# Epoch 94/100
# 2164/2164 - 4s - loss: 6.0218e-04 - 4s/epoch - 2ms/step
# Epoch 95/100
# 2164/2164 - 3s - loss: 6.0060e-04 - 3s/epoch - 1ms/step
# Epoch 96/100
# 2164/2164 - 3s - loss: 5.9906e-04 - 3s/epoch - 1ms/step
# Epoch 97/100
# 2164/2164 - 3s - loss: 6.0364e-04 - 3s/epoch - 1ms/step
# Epoch 98/100
# 2164/2164 - 4s - loss: 6.0957e-04 - 4s/epoch - 2ms/step
# Epoch 99/100
# 2164/2164 - 3s - loss: 5.9731e-04 - 3s/epoch - 1ms/step
# Epoch 100/100
# 2164/2164 - 3s - loss: 6.0208e-04 - 3s/epoch - 1ms/step
# 68/68 [==============================] - 0s 1ms/step
# 17/17 [==============================] - 0s 2ms/step

# %%
# invert predictions
trainPredict = scaler_output.inverse_transform(trainPredict)
trainY = scaler_output.inverse_transform([trainY])
testPredict = scaler_output.inverse_transform(testPredict)
testY = scaler_output.inverse_transform([testY])

# %%
# calculate RMSE for LSTM
score = np.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Score: %.5f RMSE' % (score))

# calculate MSE for LSTM
score = mean_squared_error(testY[0], testPredict[:,0])
print('Score: %.5f MSE' % (score))

# calculate MAE for LSTM
score = mean_absolute_error(testY[0], testPredict[:,0])
print('Score: %.5f MAE' % (score))

# calculate R2 for LSTM
score = r2_score(testY[0], testPredict[:,0])
print('Score: %.5f R2' % (score))
# Out:
# Score: 71.97247 RMSE
# Score: 5180.03712 MSE
# Score: 56.86367 MAE
# Score: 0.97469 R2

# %%
# shift train predictions for plotting
trainPredictPlot = np.empty_like(time_series)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# shift test predictions for plotting
testPredictPlot = np.empty_like(time_series)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(time_series)-1, :] = testPredict

# %%
# plot baseline and predictions
plt.figure(figsize=(10,6))
plt.plot(scaler_actual.inverse_transform(time_series),color="#a3a1a0",linewidth='1.5',label='actual data')
plt.plot(trainPredictPlot,color='red',linewidth='0.1',label='train')
plt.plot(testPredictPlot,color='blue',linewidth='0.1',label='test')
plt.title('LSTM Model Without Economic Indicators')
plt.xlabel('Time')
plt.ylabel('USD/IDR Exchange Rate')
plt.legend()
plt.show()

# %%
fb = pd.read_csv('/content/fbprophet.csv', index_col=0,)
fb = fb[5:]
fb
# Out:
#             fbprophet Model
# Date
# 2021-05-10     14349.448251
# 2021-05-11     14248.818203
# 2021-05-12     14256.681703
# 2021-05-13     14302.131371
# 2021-05-14     14250.023139
# ...                     ...
# 2023-05-24     14720.862351
# 2023-05-25     14729.063820
# 2023-05-26     14709.089446
# 2023-05-29     14781.410570
# 2023-05-30     14769.322337
#
# [537 rows x 1 columns]

# %%
df2 = pd.DataFrame(testPredictPlot)
df2 = df2[2171:2708]
df2.columns = ['LSTM Predicted','2','3','4']
df2=df2.drop(['2','3','4'],axis=1)
df2
# Out:
#       LSTM Predicted
# 2171    14490.616211
# 2172    14454.755859
# 2173    14510.223633
# 2174    14457.879883
# 2175    14368.258789
# ...              ...
# 2703    14886.631836
# 2704    14898.727539
# 2705    14933.471680
# 2706    14940.197266
# 2707    14921.229492
#
# [537 rows x 1 columns]

# %%
# Create a DataFrame to store predicted values
predicted_data = pd.DataFrame({'Date': fb.index, 'LSTM Model': df2['LSTM Predicted']})


# Export predicted values to a CSV file
predicted_data.to_csv('LSTM with no econ.csv', index=False)
